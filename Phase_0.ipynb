# %% [markdown]
# #### Group-30-HCDR
# ##                   HOME CREDIT DEFAULT RISK PREDICTION

# %% [markdown]
# #### Group Members:
# - Parth Kapil(pkapil@iu.edu)
# - Shiwani Rajagopalan(srajago@iu.edu)
# - Shubhangi Mishra(shubmish@iu.edu)
# - Suma Priya Davuluri(sdavulu@iu.edu

# %% [markdown]
# ![snap.png](attachment:snap.png)

# %% [markdown]
# ## Abstract
#
# Credit Rating is one of the most important parameters which is used for various purposes like opening a new bank account, getting a credit card, and availing home loan among others. A good credit rating increases the chances of approval for all the above-mentioned scenarios. Still, in many cases, we see that the customers tend to not have a credit rating which makes them less competitive in loan approval. Additionally, credit rating solely is not responsible for the loan approval. Thereby, in our project, we will address all the factors which are important for an individual to acquire a loan some of which are monthly income, previous loan applications, previous loan history, and loan repayment history among others. Further, for analyzing our results we are using namely three kinds of models categorized as Probabilistic models comprising Naïve Bayes and Maximum Likelihood Estimation second being tree-based models including Random Forest, XG Boost, and Decision Trees followed by general ML algorithms such as Linear Regression, Logistic Regression, K Nearest neighbors and SVM. Lastly to compare our results we are using metrics such as Confusion matrix, ROC/AUC curves, etc.

# %% [markdown]
# ## DATA DESCRIPTION
#
# #### In this project, we will be working on the Home Credit Default Risk dataset which is taken and adapted from the dataset hosted on Kaggle.
#
# #### There are eight important tables (or CSV files) present in the dataset which needs to be used for analysing the results. The tables are as follows:
#
# 1.	application_{train|test}.csv
# •	This is the primary table split into two files for Train (with TARGET) and Test (without TARGET)
# •	Each row represents a single loan
#
#
# 2.	bureau.csv
# •	 It consists of data concerning the client’s previous credits from other financial institutions.
# •	For every loan there are as many rows as the number of credits the client had in the Credit Bureau before the application date.
#
#
# 3.	bureau_balance.csv
# •	It consists of monthly data about the previous credits in the bureau table.
# •	Each row is one month of a previous credit, and a single previous credit can have multiple rows, one for each month of the credit length.
#
#
# 4.	POS_CASH_balance.csv
# •	It consists of monthly data about the previous point of sale.
# •	Each row is one month of a previous point of sale or cash loan, and a single previous loan can have many rows.
#
#
# 5.	credit_card_balance.csv
# •	It consists of the monthly data about previous credit cards customers for Home Credit.
# •	Each row is one month of a credit card balance, and a single credit card can have multiple rows.
#
#
# 6.	previous_application.csv
# •	It consists of all previous applications for Home Credit loans for the customers who have loans in the given sample.
# •	There is one row for each previous application related to loans in our data sample.
#
#
# 7.	installments_payments.csv
# •	It consists of the data related to payment history for previous loans at Home Credit.
# •	There are two rows one for every payment made while the other for every missed payment.
#
#
# 8.	HomeCredit_columns_description.csv
# •	This table (or files) contains the description for each column(or feature) present in each of the above-mentioned data files.

# %% [markdown]
# ## MACHINE LEARNING ALGORITHMS AND METRICS
#
# For classification, we are going to use Naive Bayes, Logistic Regression, Random Forrest, XGBoost, SVM, and Multilayer perceptron using PyTorch. We will use Naive Bayes as our baseline model. After performing feature engineering on the data, we will go ahead and apply more complex models like Logistic regression and SVM with different kernel methods. We will compare the results of these models with tree-based models such as Random Forest and XGBoost. Finally, we will use Pytorch to implement Multi-layered perceptron and compare its result with other machine learning models we used in our analysis.
#
# **Metrics:**
#
# The data for this project is imbalanced because of which accuracy cannot be used as an error metric.
#
# Basic Definitions:
#
# TP - True Positive
#
# TF - True Negative
#
# FP - False Positive
#
# FN - False Negative
#
# For imbalanced data, we can use the following metrics to find the performance of the model.
#
# AUC (Area Under Curve):
#
# AUC is used because the Kaggle competition requires contests to use AUC as a performance metric and also since depending on the value of AUC we can say whether if the result has false positives (Type 1 error), false negatives (Type 2 error) or not.
#
# ![AUC-2.png](attachment:AUC-2.png)

# %% [markdown]
# Confusion matrix:
#
# Confusion matrix gives a direct comparisons of the true positive, true negative, false positive, and false negative and also confusion matrix is used to calculate AUC, recall, and precision.
#
# confusion matrix gives the following values:True Positive, True Negative, False Positive, False Negative.

# %% [markdown]
# Precision:
#
# is the fraction of relevant instances among the retrieved instances.
#
# ![precision-2.png](attachment:precision-2.png)

# %% [markdown]
# Recall:
#
# is the fraction of relevant instances that were retrieved.
#
# ![recall-2.png](attachment:recall-2.png)

# %% [markdown]
# F1 score :
#
# F1 score is used to compare the performance of precision and recall when they are both high by combining both of them.
#
# ![f1%20score-2.png](attachment:f1%20score-2.png)

# %% [markdown]
# Log loss:
#
# Finally, we use log loss to find how close the predicted probability is to the true value.
#
# ![log%20loss-2.png](attachment:log%20loss-2.png)

# %% [markdown]
# ## MACHINE LEARNING PIPELINES

# %% [markdown]
# ![Screen%20Shot%202022-04-05%20at%206.15.49%20PM.png](attachment:Screen%20Shot%202022-04-05%20at%206.15.49%20PM.png)

# %% [markdown]
# After checking if data has any missing values and giving input, we will proceed with data preprocessing,
# and then apply StandardScaler and MinMaxScaler to scale the data before we could
# apply any algorithms. Later, on our data, we will be using the following algorithms:
# Logistic Regression, SVM, Random Forest, XG Boost, Naive Bayes, Neural Networks.
#
# Then we will go ahead and compare prediction accuracies for all these models and their metrics and compare to
# predict best model among them.

# %% [markdown]
# # PROJECT TIMELINE

# %% [markdown]
# ![timeline.png](attachment:timeline.png)

# %% [markdown]
# All of us will be working on the project. But, each one of us took the responsibility for a specific task in the project:
#
# - Shubhangi will be responsible for EDA and the baseline model.
# - Shiwani and Suma will be responsible for feature engineering and tunning hyperparameter for the models.
# - Parth will be responsible for working on the neural networks and generating the final report by analyzing all the models.
